# %% [markdown]
# <a href="https://colab.research.google.com/github/Iker-hub/daw_dwes_python_clase1/blob/main/daw_dwes_python_clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python

# %%
#versión de python
# !python --version
# Out:
# Python 3.8.10

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (7.1.2)

# %%
#cuaderno de jupyter
lenguaje = 'Python 3.9'

# %%
print(lenguaje)
# Out:
# Python 3.9

# %%
lenguaje
# Out:
# 'Python 3.9'

# %%
def ejemplo():
  return 3

# %%
ejemplo()
# Out:
# 3

# %%
lenguaje = 'Python 3.9'
print(lenguaje)
lenguaje
def ejemplo2():
  return 32
ejemplo2()
# Out:
# Python 3.9
# 32

# %%
from PIL import Image
im = Image.open('foto.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3840x2160 at 0x7F3FF18DF160>
